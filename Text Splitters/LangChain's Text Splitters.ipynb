# %% [markdown]
# ### What are Text Splitters and Why They are Useful
# #### Introduction
#
# Large Language Models, while recognized for creating human-like text, can also "hallucinate" and produce seemingly plausible yet incorrect or nonsensical information. Interestingly, this tendency can be advantageous in creative tasks, as it generates a range of unique and imaginative ideas, sparking new perspectives and driving the creative process. However, this poses a challenge in situations where accuracy is critical, such as code reviews, insurance-related tasks, or research question responses.
#
# One approach to mitigating hallucination is to provide documents as sources of information to the LLM and ask it to generate an answer based on the knowledge extracted from the document. This can help reduce the likelihood of hallucination, and users can verify the information with the source document.
#
# Let's discuss the pros and cons of this approach:
#
# Pros:
#
#     Reduced hallucination: By providing a source document, the LLM is more likely to generate content based on the given information, reducing the chances of creating false or irrelevant information.
#     Increased accuracy: With a reliable source document, the LLM can generate more accurate answers, especially in use cases where accuracy is crucial.
#     Verifiable information: Users can cross-check the generated content with the source document to ensure the information is accurate and reliable.
#
# Cons:
#
#     Limited scope: Relying on a single document may limit the scope of the generated content, as the LLM will only have access to the information provided in the document.
#     Dependence on document quality: The accuracy of the generated content heavily depends on the quality and reliability of the source document. The LLM will likely generate incorrect or misleading content if the document contains inaccurate or biased information.
#     Inability to eliminate hallucination completely: Although providing a document as a base reduces the chances of hallucination, it does not guarantee that the LLM will never generate false or irrelevant information.
#
# Addressing another challenge, LLMs have a maximum prompt size, preventing them from feeding entire documents. This makes it crucial to divide documents into smaller parts, and Text Splitters prove to be extremely useful in achieving this. Text Splitters help break down large text documents into smaller, more digestible pieces that language models can process more effectively.
#
# Using a Text Splitter can also improve vector store search results, as smaller segments might be more likely to match a query. Experimenting with different chunk sizes and overlaps can be beneficial in tailoring results to suit your specific needs.
#
# #### Customizing Text Splitter
#
# When handling lengthy pieces of text, it's crucial to break them down into manageable chunks. This seemingly simple task can quickly become complex, as keeping semantically related text segments intact is essential. The definition of "semantically related" may vary depending on the type of text. In this article, we'll explore various strategies to achieve this.
#
# At a high level, text splitters follow these steps:
#
#     Divide the text into small, semantically meaningful chunks (often sentences).
#     Combine these small chunks into a larger one until a specific size is reached (determined by a particular function).
#     Once the desired size is attained, separate that chunk as an individual piece of text, then start forming a new chunk with some overlap to maintain context between segments.
#
# Consequently, there are two primary dimensions to consider when customizing your text splitter:
#
#     The method used to split the text
#     The approach for measuring chunk size
#
# #### Character Text Splitter
#
# This type of splitter can be used in various scenarios where you must split long text pieces into smaller, semantically meaningful chunks. For example, you might use it to split a long article into smaller chunks for easier processing or analysis. The splitter allows you to customize the chunking process along two axes - chunk size and chunk overlap - to balance the trade-offs between splitting the text into manageable pieces and preserving semantic context between chunks.

# %%
workingFolder='C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\'

# %%
from langchain.document_loaders import PyPDFLoader
loader = PyPDFLoader(workingFolder+"The One Page Linux Manual.pdf")
pages = loader.load_and_split()

# %%
from langchain.text_splitter import CharacterTextSplitter

text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=20)
texts = text_splitter.split_documents(pages)

print(texts[0])

print (f"You have {len(texts)} documents")
print ("Preview:")
print (texts[0].page_content)
# Out:
# page_content='THE ONE     PAGE LINUX MANUALA summary of useful Linux commands\nVersion 3.0 May 1999 squadron@powerup.com.au\nStarting & Stopping\nshutdown -h now Shutdown the system now and do not\nreboot\nhalt Stop all processes - same as above\nshutdown -r 5 Shutdown the system in 5 minutes and\nreboot\nshutdown -r now Shutdown the system now and reboot\nreboot Stop all processes and then reboot - same\nas above\nstartx Start the X system\nAccessing & mounting file systems\nmount -t iso9660 /dev/cdrom\n/mnt/cdromMount the device cdrom\nand call it cdrom under the\n/mnt directory\nmount -t msdos /dev/hdd\n/mnt/ddriveMount hard disk “d” as a\nmsdos file system and call\nit ddrive under the /mnt\ndirectory\nmount -t vfat /dev/hda1\n/mnt/cdriveMount hard disk “a” as a\nVFAT file system and call it\ncdrive under the /mnt\ndirectory\numount /mnt/cdrom Unmount the cdrom\nFinding files and text within files\nfind / -name  fname Starting with the root directory, look\nfor the file called fname\nfind / -name ”*fname* ” Starting with the root directory, look\nfor the file containing the string fname\nlocate missingfilename Find a file called missingfilename\nusing the locate command - this\nassumes you have already used the\ncommand updatedb (see next)\nupdatedb Create or update the database of files\non all file systems attached to the linux\nroot directory\nwhich missingfilename Show the subdirectory containing the\nexecutable file  called missingfilename\ngrep textstringtofind\n/dirStarting with the directory called dir ,\nlook for and list all files containing\ntextstringtofind\nThe X Window System\nxvidtune Run the X graphics tuning utility\nXF86Setup Run the X configuration menu with\nautomatic probing of graphics cards\nXconfigurator Run another X configuration menu with\nautomatic probing of graphics cards\nxf86config Run a text based X configuration menu\nMoving, copying, deleting & viewing files\nls -l List files in current directory using\nlong format\nls -F List files in current directory and\nindicate the file type\nls -laC List all files in current directory in\nlong format and display in columnsrm name Remove a file or directory called\nname\nrm -rf name Kill off an entire directory and all it’s\nincludes files and subdirectories\ncp filename\n/home/dirnameCopy the file called filename to the\n/home/dirname directory\nmv filename\n/home/dirnameMove the file called filename to the\n/home/dirname directory\ncat filetoview Display the file called filetoview\nman -k keyword Display man pages containing\nkeyword\nmore filetoview Display the file called filetoview one\npage at a time, proceed to next page\nusing the spacebar\nhead filetoview Display the first 10 lines of the file\ncalled filetoview\nhead -20 filetoview Display the first 20 lines of the file\ncalled filetoview\ntail filetoview Display the last 10 lines of the file\ncalled filetoview\ntail -20 filetoview Display the last 20 lines of the file\ncalled filetoview\nInstalling software for Linux\nrpm -ihv name.rpm Install the rpm package called name\nrpm -Uhv name.rpm Upgrade the rpm package called\nname\nrpm -e package Delete the rpm package called\npackage\nrpm -l package List the files in the package called\npackage\nrpm -ql package List the files and state the installed\nversion of the package called\npackage\nrpm -i --force package Reinstall the rpm package called\nname having deleted parts of it (not\ndeleting using rpm -e)\ntar -zxvf archive.tar.gz or\ntar -zxvf archive.tgzDecompress the files contained in\nthe zipped and tarred archive called\narchive\n./configure Execute the script preparing the\ninstalled files for compiling\nUser Administration\nadduser accountname Create a new user call accountname\npasswd accountname Give accountname a new password\nsu Log in as superuser from current login\nexit Stop being superuser and revert to\nnormal user\nLittle known tips and tricks\nifconfig List ip addresses for all devices on\nthe machine\napropos subject List  ...
# You have 2 documents
# Preview:
# THE ONE     PAGE LINUX MANUALA summary of useful Linux commands
# Version 3.0 May 1999 squadron@powerup.com.au
# Starting & Stopping
# shutdown -h now Shutdown the system now and do not
# reboot
# halt Stop all processes - same as above
# shutdown -r 5 Shutdown the system in 5 minutes and
# reboot
# shutdown -r now Shutdown the system now and reboot
# reboot Stop all processes and then reboot - same
# as above
# startx Start the X system
# Accessing & mounting file systems
# mount -t iso9660 /dev/cdrom
# /mnt/cdromMount the device cdrom
# and call it cdrom under the
# /mnt directory
# mount -t msdos /dev/hdd
# /mnt/ddriveMount hard disk “d” as a
# msdos file system and call
# it ddrive under the /mnt
# directory
# mount -t vfat /dev/hda1
# /mnt/cdriveMount hard disk “a” as a
# VFAT file system and call it
# cdrive under the /mnt
# directory
# umount /mnt/cdrom Unmount the cdrom
# Finding files and text within files
# find / -name  fname Starting with the root directory, look
# for the file called fname
# find / -name ”*fname* ” Starting with the root directory, look
# for the file containing the string fname
# locate missingfilename Find a file called missingfilename
# using the locate command - this
# assumes you have already used the
# command updatedb (see next)
# updatedb Create or update the database of files
# on all file systems attached to the linux
# root directory
# which missingfilename Show the subdirectory containing the
# executable file  called missingfilename
# grep textstringtofind
# /dirStarting with the directory called dir ,
# look for and list all files containing
# textstringtofind
# The X Window System
# xvidtune Run the X graphics tuning utility
# XF86Setup Run the X configuration menu with
# automatic probing of graphics cards
# Xconfigurator Run another X configuration menu with
# automatic probing of graphics cards
# xf86config Run a text based X configuration menu
# Moving, copying, deleting & viewing files
# ls -l List files in current directory using
# long format
# ls -F List files in current directory and
# indicate the file type
# ls -laC List all files in current directory in
# long format and display in columnsrm name Remove a file or directory called
# name
# rm -rf name Kill off an entire directory and all it’s
# includes files and subdirectories
# cp filename
# /home/dirnameCopy the file called filename to the
# /home/dirname directory
# mv filename
# /home/dirnameMove the file called filename to the
# /home/dirname directory
# cat filetoview Display the file called filetoview
# man -k keyword Display man pages containing
# keyword
# more filetoview Display the file called filetoview one
# page at a time, proceed to next page
# using the spacebar
# head filetoview Display the first 10 lines of the file
# called filetoview
# head -20 filetoview Display the first 20 lines of the file
# called filetoview
# tail filetoview Display the last 10 lines of the file
# called filetoview
# tail -20 filetoview Display the last 20 lines of the file
# called filetoview
# Installing software for Linux
# rpm -ihv name.rpm Install the rpm package called name
# rpm -Uhv name.rpm Upgrade the rpm package called
# name
# rpm -e package Delete the rpm package called
# package
# rpm -l package List the files in the package called
# package
# rpm -ql package List the files and state the installed
# version of the package called
# package
# rpm -i --force package Reinstall the rpm package called
# name having deleted parts of it (not
# deleting using rpm -e)
# tar -zxvf archive.tar.gz or
# tar -zxvf archive.tgzDecompress the files contained in
# the zipped and tarred archive called
# archive
# ./configure Execute the script preparing the
# installed files for compiling
# User Administration
# adduser accountname Create a new user call accountname
# passwd accountname Give accountname a new password
# su Log in as superuser from current login
# exit Stop being superuser and revert to
# normal user
# Little known tips and tricks
# ifconfig List ip addresses for all devices on
# the machine
# apropos subject List manual pages for subject
# usermount Executes graphical application for
# mounting and unmounting file
# systems

# %% [markdown]
# No universal approach for chunking text will fit all scenarios - what's effective for one case might not be suitable for another. Finding the best chunk size for your project means going through a few steps. First, clean up your data by getting rid of anything that's not needed, like HTML tags from websites. Then, pick a few different chunk sizes to test. The best size will depend on what kind of data you're working with and the model you're using.  Finally, test out how well each size works by running some queries and comparing the results. You might need to try a few different sizes before finding the best one. This process might take some time, but getting the best results from your project is worth it.
#
# #### Recursive Character Text Splitter
#
# The Recursive Character Text Splitter is a text splitter designed to split the text into chunks based on a list of characters provided. It attempts to split text using the characters from a list in order until the resulting chunks are small enough. By default, the list of characters used for splitting is ["\n\n", "\n", " ", "], which tries to keep paragraphs, sentences, and words together as long as possible, as they are generally the most semantically related pieces of text. This means that the class first tries to split the text into two new-line characters. If the resulting chunks are still larger than the desired chunk size, it will then try to split the output by a single new-line character, followed by a space character, and so on, until the desired chunk size is achieved.
#
# To use the RecursiveCharacterTextSplitter, you can create an instance of it and provide the following parameters:
#
# chunk_size : The maximum size of the chunks, as measured by the length_function (default is 100).
#
# chunk_overlap: The maximum overlap between chunks to maintain continuity between them (default is 20).
#
# length_function: parameter is used to calculate the length of the chunks. By default, it is set to len, which counts the number of characters in a chunk. However, you can also pass a token counter or any other function that calculates the length of a chunk based on your specific requirements.
#
# Using a token counter instead of the default len function can benefit specific scenarios, such as when working with language models with token limits. For example, OpenAI's GPT-3 has a token limit of 4096 tokens per request, so you might want to count tokens instead of characters to better manage and optimize your requests.
#
# Here's an example of how to use RecursiveCharacterTextSplitter.

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

loader = PyPDFLoader(workingFolder+"The One Page Linux Manual.pdf")
pages = loader.load_and_split()

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=50,
    chunk_overlap=10,
    length_function=len,
)

docs = text_splitter.split_documents(pages)
for doc in docs:
    print(doc)
# Out:
# page_content='THE ONE     PAGE LINUX MANUALA summary of useful' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='of useful Linux commands' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='Version 3.0 May 1999 squadron@powerup.com.au' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='Starting & Stopping' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='shutdown -h now Shutdown the system now and do not' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='reboot\nhalt Stop all processes - same as above' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='shutdown -r 5 Shutdown the system in 5 minutes and' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='reboot' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='shutdown -r now Shutdown the system now and reboot' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='reboot Stop all processes and then reboot - same' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='as above\nstartx Start the X system' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='Accessing & mounting file systems' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='mount -t iso9660 /dev/cdrom' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='/mnt/cdromMount the device cdrom' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='and call it cdrom under the\n/mnt directory' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='mount -t msdos /dev/hdd' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='/mnt/ddriveMount hard disk “d” as a' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='msdos file system and call' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='it ddrive under the /mnt\ndirectory' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='directory\nmount -t vfat /dev/hda1' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='/mnt/cdriveMount hard disk “a” as a' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='VFAT file system and call it\ncdrive under the /mnt' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='directory\numount /mnt/cdrom Unmount the cdrom' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='Finding files and text within files' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='find / -name  fname Starting with the root' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='the root directory, look' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='for the file called fname' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='find / -name ”*fname* ” Starting with the root' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='the root directory, look' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='for the file containing the string fname' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='locate missingfilename Find a file called' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='called missingfilename' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='using the locate command - this' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='assumes you have already used the' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='command updatedb (see next)' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='updatedb Create or update the database of files' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='on all file systems attached to the linux' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='root directory' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='which missingfilename Show the subdirectory' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='containing the' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='executable file  called missingfilename' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='grep textstringtofind' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='/dirStarting with the directory called dir ,' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='look for and list all files containing' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='textstringtofind\nThe X Window System' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='xvidtune Run the X graphics tuning utility' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='XF86Setup Run the X configuration menu with' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='automatic probing of graphics cards' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='Xconfigurator Run another X configuration menu' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='menu with' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='automatic probing of graphics cards' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='xf86config Run a text based X configuration menu' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='Moving, copying, deleting & viewing files' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='ls -l List files in current directory using' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='long format' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='ls -F List files in current directory and' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='indicate the file type' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='ls -laC List all files in current directory in' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='long format and display in columnsrm name Remove a' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='Remove a file or directory called' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='name' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='rm -rf name Kill off an entire directory and all' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='and all it’s' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='includes files and subdirectories\ncp filename' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='/home/dirnameCopy the file called filename to the' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='/home/dirname directory\nmv filename' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='/home/dirnameMove the file called filename to the' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='/home/dirname directory' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='cat filetoview Display the file called filetoview' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='man -k keyword Display man pages containing' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='keyword' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='more filetoview Display the file called filetoview' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='filetoview one' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='page at a time, proceed to next page' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='using the spacebar' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='head filetoview Display the first 10 lines of the' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='of the file' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='called filetoview' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='head -20 filetoview Display the first 20 lines of' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='lines of the file' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='called filetoview' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='tail filetoview Display the last 10 lines of the' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='of the file' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='called filetoview' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='tail -20 filetoview Display the last 20 lines of' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='lines of the file' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='called filetoview\nInstalling software for Linux' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='rpm -ihv name.rpm Install the rpm package called' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='called name' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='rpm -Uhv name.rpm Upgrade the rpm package called' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='name\nrpm -e package Delete the rpm package called' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='package' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='rpm -l package List the files in the package' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='package called' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='package' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='rpm -ql package List the files and state the' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='state the installed' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='version of the package called\npackage' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='rpm -i --force package Reinstall the rpm package' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='package called' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='name having deleted parts of it (not' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='deleting using rpm -e)\ntar -zxvf archive.tar.gz or' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='tar -zxvf archive.tgzDecompress the files' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='the files contained in' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='the zipped and tarred archive called\narchive' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='./configure Execute the script preparing the' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='installed files for compiling\nUser Administration' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='adduser accountname Create a new user call' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='user call accountname' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='passwd accountname Give accountname a new password' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='su Log in as superuser from current login' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='exit Stop being superuser and revert to' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='normal user\nLittle known tips and tricks' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='ifconfig List ip addresses for all devices on' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='the machine' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='apropos subject List manual pages for subject' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='usermount Executes graphical application for' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='mounting and unmounting file\nsystems' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 0}
# page_content='/sbin/e2fsck hda5 Execute the filesystem check' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='check utility' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='on partition hda5' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='fdformat /dev/fd0H1440 Format the floppy disk in' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='disk in device fd0' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='tar -cMf /dev/fd0 Backup the contents of the' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='of the current' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='directory and subdirectories to' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='multiple floppy disks' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='tail -f /var/log/messages Display the last 10' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='last 10 lines of the system' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='log.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='cat /var/log/dmesg Display the file containing the' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='the boot' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='time messages - useful for locating' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='problems. Alternatively, use the\ndmesg  command.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='* wildcard - represents everything. eg.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='cp from/* to  will copy all files in the' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='from directory to the to directory' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='? Single character wildcard. eg.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='cp config.? /configs will copy all files' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='beginning with the name config. in' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='the current directory to the directory' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='named configs.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='[xyz] Choice of character wildcards. eg.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='ls [xyz]* will list all files in the current' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='directory starting with the letter x, y,\nor z.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='linux single At the lilo prompt, start in single' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='in single user' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='mode. This is useful if you have' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='forgotten your password. Boot in' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='single user mode, then run the\npasswd  command.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='ps List current processes' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='kill 123 Kill a specific process eg. kill 123' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='Configuration files and what they do' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='/etc/profile System wide environment variables for' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='all users.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='/etc/fstab List of devices and their associated' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='associated mount' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='points. Edit this file to add cdroms, DOS' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='partitions and floppy drives at startup.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='/etc/motd Message of the day broadcast to all' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='to all users' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='at login.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='etc/rc.d/rc.local Bash script that is executed at' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='at the end of' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='login process. Similar to autoexec.bat in\nDOS.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='/etc/HOSTNAME Conatins full hostname including' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='including domain.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='/etc/cron.* There are 4 directories that' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='that automatically' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='execute all scripts within the directory at' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='intervals of hour, day, week or month.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='/etc/hosts A list of all know host names and IP' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='addresses on the machine.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='/etc/httpd/conf Paramters for the Apache web' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='Apache web server' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='/etc/inittab Specifies the run level that the' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='that the machine' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='should boot into.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='/etc/resolv.conf Defines IP addresses of DNS' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='of DNS servers.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='/etc/smb.conf Config file for the SAMBA server.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='server. Allows' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='file and print sharing with Microsoft\nclients.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='clients.\n/etc/X11/XF86Confi' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='gConfig file for X -Windows.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='~/.xinitrc Defines the windows manager loaded by' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='X. ~ refers to user’s home directory.File' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='permissions' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='If the command ls -l is given, a long list of file' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='of file names is' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='displayed. The first column in this list details' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='details the permissions' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='applying to the file. If a permission is missing' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='is missing for a owner,' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='group of other, it is represented by - eg.  drwxr' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='eg.  drwxr -x—x' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='Read = 4\nWrite = 2' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='Execute = 1File permissions are altered by giving' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='by giving the' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='chmod command and the appropriate' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='octal code for each user type. eg' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='chmod 7 6 4 filename will make the file' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='called filename R+W+X for the owner,' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='R+W for the group and R for others.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='chmod 7 5 5 Full permission for the owner, read' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='read and' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='execute access for the group and others.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='chmod +x filename Make the file called filename' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='filename executable' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='to all users.\nX Shortcuts - (mainly for Redhat)' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='Control|Alt  + or - Increase or decrease the' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='the screen' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='resolution. eg. from 640x480 to\n800x600' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='Alt | escape Display list of active windows' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='Shift|Control F8 Resize the selected window' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='Right click on desktop\nbackgroundDisplay menu' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='Shift|Control Altr Refresh the screen' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='Shift|Control Altx Start an xterm session\nPrinting' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='/etc/rc.d/init.d/lpd start Start the print daemon' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='/etc/rc.d/init.d/lpd stop Stop the print daemon' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='/etc/rc.d/init.d/lpd' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='statusDisplay status of the print daemon' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='lpq Display jobs in print queue' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='lprm Remove jobs from queue\nlpr Print a file' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='lpc Printer control tool' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='man subject | lpr Print the manual page called' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='called subject' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='as plain text' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='man -t subject | lpr Print the manual page called' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='called subject' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='as Postscript output' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='printtool Start X printer setup' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='setup interface~/.Xdefaults Define configuration' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='for some X -' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='applications. ~ refers to user’s home\ndirectory.' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='Get your own Official Linux Pocket Protector -' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='- includes' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='handy command summary. Visit:' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}
# page_content='www.powerup.com.au/~squadron' metadata={'source': 'C:\\Users\\jfrancis\\OneDrive - XYZ\\XYZ D Drive\\AI Journey\\Gen AI\\The One Page Linux Manual.pdf', 'page': 1}

# %% [markdown]
# #### NLTK Text Splitter
#
# The NLTKTextSplitter in LangChain is an implementation of a text splitter that uses the Natural Language Toolkit (NLTK) library to split text based on tokenizers. The goal is to split long texts into smaller chunks without breaking the structure of sentences and paragraphs.

# %%
import nltk

# %%
from langchain.text_splitter import NLTKTextSplitter

# Load a long document
with open(workingFolder+'my_file.txt', encoding= 'unicode_escape') as f:
    sample_text = f.read()

text_splitter = NLTKTextSplitter(chunk_size=500)
texts = text_splitter.split_text(sample_text)
print(texts)
# Out:
# ['Google opens up its AI language model PaLM to challenge OpenAI and GPT-3\nGoogle is offering developers access to one of its most advanced AI language models: PaLM.\n\nThe search giant is launching an API for PaLM alongside a number of AI enterprise tools\nit says will help businesses \x93generate text, images, code, videos, audio, and more from\nsimple natural language prompts.\x94\n\nPaLM is a large language model, or LLM, similar to the GPT series created by OpenAI or\nMeta\x92s LLaMA family of models.', 'Google first announced PaLM in April 2022.\n\nLike other LLMs,\nPaLM is a flexible system that can potentially carry out all sorts of text generation and\nediting tasks.\n\nYou could train PaLM to be a conversational chatbot like ChatGPT, for\nexample, or you could use it for tasks like summarizing text or even writing code.\n\n(It\x92s similar to features Google also announced today for its Workspace apps like Google\nDocs and Gmail.)']

# %% [markdown]
# However, as mentioned in your context, the NLTKTextSplitter is not specifically designed to handle word segmentation in English sentences without spaces. For this purpose, you can use alternative libraries like pyenchant or word segment.
#
# #### SpacyTextSplitter
#
# The SpacyTextSplitter helps split large text documents into smaller chunks based on a specified size. This is useful for better management of large text inputs. It's important to note that the SpacyTextSplitter is an alternative to NLTK-based sentence splitting. You can create a SpacyTextSplitter object by specifying the chunk_size parameter, measured by a length function passed to it, which defaults to the number of characters.

# %%
from langchain.text_splitter import SpacyTextSplitter

# Load a long document
with open(workingFolder+'my_file.txt', encoding= 'unicode_escape') as f:
    sample_text = f.read()

# Instantiate the SpacyTextSplitter with the desired chunk size
text_splitter = SpacyTextSplitter(chunk_size=500, chunk_overlap=20)

# Split the text using SpacyTextSplitter
texts = text_splitter.split_text(sample_text)

# Print the first chunk
print(texts[0])
# Out:
# Google opens up its AI language model PaLM to challenge OpenAI and GPT-3
#
#
# Google is offering developers access to one of its most advanced AI language models: PaLM.
#
#
# The search giant is launching an API for PaLM alongside a number of AI enterprise tools
# it says will help businesses generate text, images, code, videos, audio, and more from
# simple natural language prompts.
#
# PaLM is a large language model, or LLM, similar to the GPT series created by OpenAI or
# Metas LLaMA family of models.

# %% [markdown]
# #### MarkdownTextSplitter
#
# The MarkdownTextSplitter is designed to split text written using Markdown languages like headers, code blocks, or dividers. It is implemented as a simple subclass of RecursiveCharacterSplitter with Markdown-specific separators. By default, these separators are determined by the Markdown syntax, but they can be customized by providing a list of characters during the initialization of the MarkdownTextSplitter instance. The chunk size, which is initially set to the number of characters, is measured by the length function passed in. To customize the chunk size, provide an integer value when initializing an instance.

# %%
from langchain.text_splitter import MarkdownTextSplitter

markdown_text = """
# 

# Welcome to My Blog!

## Introduction
Hello everyone! My name is **John Doe** and I am a _software developer_. I specialize in Python, Java, and JavaScript.

Here's a list of my favorite programming languages:

1. Python
2. JavaScript
3. Java

You can check out some of my projects on [GitHub](https://github.com).

## About this Blog
In this blog, I will share my journey as a software developer. I'll post tutorials, my thoughts on the latest technology trends, and occasional book reviews.

Here's a small piece of Python code to say hello:

\``` python
def say_hello(name):
    print(f"Hello, {name}!")

say_hello("John")
\```

Stay tuned for more updates!

## Contact Me
Feel free to reach out to me on [Twitter](https://twitter.com) or send me an email at johndoe@email.com.

"""

markdown_splitter = MarkdownTextSplitter(chunk_size=100, chunk_overlap=0)
docs = markdown_splitter.create_documents([markdown_text])

print(docs)
# Out:
# [Document(page_content='# \n\n# Welcome to My Blog!', metadata={}), Document(page_content='Introduction', metadata={}), Document(page_content='Hello everyone! My name is **John Doe** and I am a _software developer_. I specialize in Python,', metadata={}), Document(page_content='Java, and JavaScript.', metadata={}), Document(page_content="Here's a list of my favorite programming languages:\n\n1. Python\n2. JavaScript\n3. Java", metadata={}), Document(page_content='You can check out some of my projects on [GitHub](https://github.com).', metadata={}), Document(page_content='About this Blog', metadata={}), Document(page_content="In this blog, I will share my journey as a software developer. I'll post tutorials, my thoughts on", metadata={}), Document(page_content='the latest technology trends, and occasional book reviews.', metadata={}), Document(page_content="Here's a small piece of Python code to say hello:", metadata={}), Document(page_content='\\``` python\ndef say_hello(name):\n    print(f"Hello, {name}!")\n\nsay_hello("John")\n\\', metadata={}), Document(page_content='Stay tuned for more updates!', metadata={}), Document(page_content='Contact Me', metadata={}), Document(page_content='Feel free to reach out to me on [Twitter](https://twitter.com) or send me an email at', metadata={}), Document(page_content='johndoe@email.com.', metadata={})]

# %% [markdown]
# The MarkdownTextSplitter offers a practical solution for dividing text while preserving the structure and meaning provided by Markdown formatting. By recognizing the Markdown syntax (e.g., headings, lists, and code blocks), you can intelligently divide the content based on its structure and hierarchy, resulting in more semantically coherent chunks. This splitter is especially valuable when managing extensive Markdown documents.
#
# #### TokenTextSplitter
#
# The main advantage of using TokenTextSplitter over other text splitters, like CharacterTextSplitter, is that it respects the token boundaries, ensuring that the chunks do not split tokens in the middle. This can be particularly helpful in maintaining the semantic integrity of the text when working with language models and embeddings.
#
# This type of splitter breaks down raw text strings into smaller pieces by initially converting the text into BPE (Byte Pair Encoding) tokens, and subsequently dividing these tokens into chunks. It then reassembles the tokens within each chunk back into text.

# %%
from langchain.text_splitter import TokenTextSplitter

# Load a long document
with open(workingFolder+'my_file.txt', encoding= 'unicode_escape') as f:
    sample_text = f.read()

# Initialize the TokenTextSplitter with desired chunk size and overlap
text_splitter = TokenTextSplitter(chunk_size=100, chunk_overlap=50)

# Split into smaller chunks
texts = text_splitter.split_text(sample_text)
print(texts[0])
# Out:
# Google opens up its AI language model PaLM to challenge OpenAI and GPT-3
# Google is offering developers access to one of its most advanced AI language models: PaLM.
# The search giant is launching an API for PaLM alongside a number of AI enterprise tools
# it says will help businesses generate text, images, code, videos, audio, and more from
# simple natural language prompts.
#
# PaLM is a large language model, or LLM,

# %% [markdown]
# The chunk_size parameter sets the maximum number of BPE tokens in each chunk, while chunk_overlap defines the number of overlapping tokens between adjacent chunks. By modifying these parameters, you can fine-tune the granularity of the text chunks.
#
# One potential drawback of using TokenTextSplitter is that it may require additional computation when converting text to BPE tokens and back. If you need a faster and simpler text-splitting method, you might consider using CharacterTextSplitter, which directly splits the text based on character count, offering a more straightforward approach to text segmentation.
